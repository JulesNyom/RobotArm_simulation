# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
gas = pd.read_csv('gas_prices.csv')

plt.ifigure(figsize =(8,5))

plt.plot(ga.year, gas.USA, 'r.-', label="USA")
plt.plot(ga.year, gas.Canada, 'b.-', label="Canada")

plt.title('USA vs Canda Gas prices')
plt.ylabel('Dollars/Gallon')
plt.legend()

plt.xticks(gas.Year[::3].tolist()+[2011])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 gas = pd.read_csv('gas_prices.csv')
#       3 plt.ifigure(figsize =(8,5))
#       5 plt.plot(ga.year, gas.USA, 'r.-', label="USA")
#
# NameError: name 'pd' is not defined
